# %%
from pyspark.sql import SparkSession
from pyspark.sql.types
import time

# %%
spark = SparkSession.builder.appName("DemoSparkApp").getOrCreate()

# %%
data =[1,2,3,4,5]

# %%
rdd = spark.sparkContext.parallelize(df_random)
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/site-packages/pyspark/serializers.py", line 459, in dumps
#     return cloudpickle.dumps(obj, pickle_protocol)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/pyspark/cloudpickle/cloudpickle_fast.py", line 73, in dumps
#     cp.dump(obj)
#   File "/usr/local/lib/python3.12/site-packages/pyspark/cloudpickle/cloudpickle_fast.py", line 632, in dump
#     return Pickler.dump(self, obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: cannot pickle '_thread.RLock' object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/pyspark/serializers.py:459, in CloudPickleSerializer.dumps(self, obj)
#     458 try:
# --> 459     return cloudpickle.dumps(obj, pickle_protocol)
#     460 except pickle.PickleError:
#
# ...

# %%
for element in rdd.collect():
    print(element)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
from pyspark.sql.functions import col,desc,sum,avg

from pyspark.sql.functions import col, desc, sum, avg
# Initialize
spark = SparkSession.builder.appName("SparkCompleteNotes").getOrCreate()
# Create Base DataFrame
data = [
    (1, "Alice", "Engineering", 75000, 25),
    (2, "Bob", "Marketing", 60000, 30),
    (3, "Charlie", "Engineering", 80000, 35),
    (4, "David", "Sales", 65000, 28),
    (5, "Eve", "Marketing", 70000, 32)
]
columns = ["Id", "Name", "Department", "Salary", "Age"]
df = spark.createDataFrame(data, columns);
# Out:
# 26/06/12 05:37:46 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
df_select = df.select("Name","Department","Salary")

# %%
df_select.show()
# Out:
# +-------+-----------+------+
# |   Name| Department|Salary|
# +-------+-----------+------+
# |  Alice|Engineering| 75000|
# |    Bob|  Marketing| 60000|
# |Charlie|Engineering| 80000|
# |  David|      Sales| 65000|
# |    Eve|  Marketing| 70000|
# +-------+-----------+------+

# %%
df_filter = df.filter(col("Salary")>65000)

# %%
from pyspark.sql.functions import col, lit, concat

# %%
df_filter.show()
# Out:
# +---+-------+-----------+------+---+
# | Id|   Name| Department|Salary|Age|
# +---+-------+-----------+------+---+
# |  1|  Alice|Engineering| 75000| 25|
# |  3|Charlie|Engineering| 80000| 35|
# |  5|    Eve|  Marketing| 70000| 32|
# +---+-------+-----------+------+---+

# %%
df = spark.read

# %%
 df.write.mode("overwrite").parquet("output/employees.parquet"

# %%
df_random = spark.range(0, 1000000).withColumn("value",col("id") * 10000)

# %%
df_random.take(10)
# Out:
# [Row(id=0, value=0),
#  Row(id=1, value=10000),
#  Row(id=2, value=20000),
#  Row(id=3, value=30000),
#  Row(id=4, value=40000),
#  Row(id=5, value=50000),
#  Row(id=6, value=60000),
#  Row(id=7, value=70000),
#  Row(id=8, value=80000),
#  Row(id=9, value=90000)]

# %%
print("Before Partition",df_random.rdd.getNumPartitions())
# Out:
# Before Partition 2

# %%
df_repartitioned = df.repartition(20)

# %%
print("After Partition",df_repartitioned.rdd.getNumPartitions())
# Out:
# [Stage 3:>                                                          (0 + 2) / 2]
# After Partition 20

# %%
df_repartitioned.write.mode("overwrite").csv("output/employees.csv", header=True)

# %%
df_coalasced = df_repartitioned.coalesce(2)

# %%
print("After Reacoalasced",df_coalasced.rdd.getNumPartitions())
# Out:
# After Reacoalasced 2

# %%
df_coalasced.write.mode("overwrite").csv("output/employeescoalasced.csv", header=True)

# %%
df_coalasced.write.mode("overwrite").csv("output/employees.csv", header=True)

# %%
optimised_df = df_random.filter(col("value") > 500).filter(col("id") < 5000000 ).select("id","value")

# %%
start_time = time.time()
count_uncached = optimised_df.count()
end_time = time.time()
print(f"1 . Optimized Execution | Count: {count_uncached} | Time: {round(end_time-start_time,4)}")
# Out:
# 1 . Optimized Execution | Count: 999999 | Time: 0.24

# %%
optimised_df.cache()
# Out:
# DataFrame[id: bigint, value: bigint]

# %%
start_time = time.time()
count_uncached = optimised_df.count()
end_time = time.time()
print(f"1 . Optimized Execution | Count: {count_uncached} | Time: {round(end_time-start_time)}")
# Out:
# 1 . Optimized Execution | Count: 999999 | Time: 1

# %%
optimised_df.unpersist()
print("\n--> Unpersisted Dataframe to free up memory.")
# Out:
# --> Unpersisted Dataframe to free up memory.

# %%
data = [
    ("Aryan",23),
    ("Abinav",12),
    ("obaid",20),
    ("Huzaif",21)
]
columns = ["Name","Age"]
df = spark.createDataFrame(data, columns);

# %%
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df1.show()
#
# AttributeError: 'list' object has no attribute 'show'

# %%
def candrive(age):
    if age > 18:
        print("he can drive")
    else:
        print("cannot drive")
